# %%
# ===============================================================
# --- Checking Cuda Availability ---
# ===============================================================

import torch

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.11.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
# ===============================================================
# --- Install Required Packages ---
# ===============================================================

# !pip install mulaconf
# !pip install xgboost
# Out:
# Collecting mulaconf
#   Downloading mulaconf-0.3.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from mulaconf) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from mulaconf) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from mulaconf) (1.6.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mulaconf) (2.11.0+cu128)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mulaconf) (2.2.3)
# Requirement already satisfied: tqdm>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from mulaconf) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->mulaconf) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->mulaconf) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->mulaconf) (2026.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->mulaconf) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->mulaconf) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (3.32.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->mulaconf) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mulaconf) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->mulaconf) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->mulaconf) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->mulaconf) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->mulaconf) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->mulaconf) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->mulaconf) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->mulaconf) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->mulaconf) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->mulaconf) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->mulaconf) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->mulaconf) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->mulaconf) (1.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->mulaconf) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->mulaconf) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->mulaconf) (3.0.3)
# Downloading mulaconf-0.3.0-py3-none-any.whl (30 kB)
# Installing collected packages: mulaconf
# Successfully installed mulaconf-0.3.0
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.3)
# Requirement already satisfied: nvidia-nccl-cu13 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.31.2)

# %%
# ===========================================================
# --- Script for experiments ----
# ===========================================================
import pandas as pd
import numpy as np
import torch
import time
import os
import gc
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from tqdm import tqdm
import requests
import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s"
)


from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputClassifier
from xgboost import XGBClassifier

from mulaconf.icp_predictor import InductiveConformalPredictor
import mulaconf.constants as constants

constants._EMPTY_CUDA_CACHE = False


# --- Setup  ---
# Dataset: "yeast" or "tmc2007_500"
dataset = "yeast"
calibration_size = 0.3
test_size = 0.1
n_experiments = 1

#Measures: 'mahalanobis' or 'norm'
measures = ['mahalanobis', 'norm']


# Note: The default case will always run
weight_configs = [
    (0.5, 0.5),
    (0.25, 0.75),
    (2.0, 1.0)
]


if (0.0, 0.0) in weight_configs:
    weight_configs.remove((0.0, 0.0))


penalty_weight_cases = {
    f"W_H={w_h}, W_C={w_c}": (w_h, w_c)
    for w_h, w_c in weight_configs
}


# Download data from data folder on GitHub
data_dir = os.path.join(os.getcwd(), f"data/{dataset}")
os.makedirs(data_dir, exist_ok=True)

base_url = f"https://raw.githubusercontent.com/k-kostas/MuLaConf/main/examples/data/{dataset}"

x_output_path = os.path.join(data_dir, f"X_{dataset}.csv")
y_output_path = os.path.join(data_dir, f"y_{dataset}.csv")

# Download X data
print(f"Downloading X_{dataset}.csv...")
response_x = requests.get(f"{base_url}/X_{dataset}.csv", allow_redirects=True, timeout=60)
response_x.raise_for_status()
with open(x_output_path, "wb") as f:
    f.write(response_x.content)

# Download y data
print(f"Downloading y_{dataset}.csv...")
response_y = requests.get(f"{base_url}/y_{dataset}.csv", allow_redirects=True, timeout=60)
response_y.raise_for_status()
with open(y_output_path, "wb") as f:
    f.write(response_y.content)

out_dir = f"{dataset}_experiments"
os.makedirs(out_dir, exist_ok=True)

print(f"Loading {dataset} dataset...")
X = pd.read_csv(x_output_path).values
y = pd.read_csv(y_output_path).values
print(f"X shape: {X.shape}, y shape: {y.shape}")

classes = y.shape[1]

# --- Check devices ---
devices = ['cpu']
if torch.cuda.is_available():
    devices.append('cuda')
    print("CUDA detected! Will run a fair CPU vs GPU benchmark.")
else:
    print("No CUDA detected. Running CPU only.")


# --- Dataset partitioning function ---
def generate_experiments(X, y, n_experiments=10, test_size=0.10, calibration_size=0.30, random_state=42):
    if test_size <= 0 or test_size >= 1:
        raise ValueError("test_size must be in (0, 1).")

    if calibration_size <= 0 or calibration_size >= 1:
        raise ValueError("calibration_size must be in (0, 1).")

    if test_size + calibration_size >= 1:
        raise ValueError(
            "test_size + calibration_size must be < 1."
        )

    indices = np.arange(len(X))

    internal_cal_size = calibration_size / (1.0 - test_size)

    for experiment in range(n_experiments):
        split_seed = random_state + experiment

        traincal_idx, test_idx = train_test_split(
            indices,
            test_size=test_size,
            shuffle=True,
            random_state=split_seed
        )

        train_idx, calib_idx = train_test_split(
            traincal_idx,
            test_size=internal_cal_size,
            shuffle=True,
            random_state=split_seed + 100000
        )

        yield (experiment, train_idx, calib_idx, test_idx,)


# --- Timing helper functon ---
def get_time(device):
    """Ensures GPU operations are finished before stopping the stopwatch."""
    if str(device).startswith('cuda'):
        torch.cuda.synchronize()
    return time.perf_counter()


# --- CUDA Warmup function ---
def warmup_cuda():
    """Performs CUDA warmup to avoid cold-start penalties on first operations."""
    if torch.cuda.is_available():
        print("\nWarming up CUDA context to prevent Fold 1 timing penalties...")
        for _ in range(3):
            _ = torch.rand(1000, 1000, device='cuda') @ torch.rand(1000, 1000, device='cuda')
        torch.cuda.synchronize()
        torch.cuda.empty_cache()


if 'cuda' in devices:
    warmup_cuda()


# --- Format MultiOutputClassifier probabilities for MuLaConf ---
def get_positive_probs(proba_list):
    """Converts a list of (N, 2) arrays into an (N, C) matrix of positive class probabilities."""
    return np.column_stack([p[:, 1] for p in proba_list])

# --- Cleanup memory ---
def cleanup_memory(device):
    """Aggressive memory cleanup."""
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()


# --- Experiment Parameters ---
alphas = [round(a, 2) for a in np.arange(0.01, 1.00, 0.01)]


# Separate default case from penalty update cases
default_weight_case = ("W_H=0, W_C=0", (0.0, 0.0))

# All weight cases for results storage
all_weight_cases = {default_weight_case[0]: default_weight_case[1], **penalty_weight_cases}

# Generate all measure-weight combinations
all_cases = [f"{m[:3].upper()} | {w}" for m in measures for w in all_weight_cases.keys()]
print(f"Total number of weight-case combinations: {len(all_cases)}")
print(f"Cases: {all_cases}")

# Data structures to hold results across all experiments
coverage_results = {device: {case: np.zeros((n_experiments, len(alphas))) for case in all_cases} for device in devices}
size_results = {device: {case: np.zeros((n_experiments, len(alphas))) for case in all_cases} for device in devices}

# Timing records for default case (init, calibrate, predict, evaluate)
default_timing_records = []

# Timing records for penalty update cases (penalty_update, predict, evaluate)
penalty_timing_records = []

total_start_time = time.perf_counter()

# --- Experiments Loop ---
print(f"\nStarting {n_experiments} experiment(s)...")
experiment_iterator = tqdm(
    generate_experiments(
        X,
        y,
        n_experiments=n_experiments,
        test_size=test_size,
        calibration_size=calibration_size,
        random_state=42
    ),
    total=n_experiments,
    desc="Experiments"
)

for iteration, train_index, calib_index, test_index in experiment_iterator:

    X_train = X[train_index]
    y_train = y[train_index]

    X_calib = X[calib_index]
    y_calib = y[calib_index]

    X_test = X[test_index]
    y_test = y[test_index]

    # =====================================================================
    # STEP A: Train XGBoost Base Model ONCE per fold
    # =====================================================================
    base_model = MultiOutputClassifier(XGBClassifier(n_estimators=50, tree_method='hist', random_state=iteration))
    base_model.fit(X_train, y_train)

    train_probs = get_positive_probs(base_model.predict_proba(X_train))
    calib_probs = get_positive_probs(base_model.predict_proba(X_calib))
    test_probs = get_positive_probs(base_model.predict_proba(X_test))

    # =====================================================================
    # STEP B: Raw ICP Engine Benchmark (CPU vs GPU)
    # =====================================================================
    for device in devices:
        for measure in measures:
            cleanup_memory(device)

            # =============================================================
            # DEFAULT CASE: W_H=0, W_C=0 (Full timing: init, calibrate, predict, evaluate)
            # =============================================================
            default_name, (default_w_h, default_w_c) = default_weight_case
            case_key = f"{measure[:3].upper()} | {default_name}"

            default_timing = {
                'Iteration': iteration,
                'Device': device,
                'Measure': measure,
                'Weight_Case': default_name,
                'W_H': default_w_h,
                'W_C': default_w_c
            }

            # --- Init Time ---
            t0 = get_time(device)
            icp = InductiveConformalPredictor(
                predicted_probabilities=train_probs,
                true_labels=y_train,
                measure=measure,
                weight_hamming=default_w_h,
                weight_cardinality=default_w_c,
                device=device
            )
            default_timing['ICP_Init_Time'] = get_time(device) - t0

            # --- Calibrate Time ---
            t0 = get_time(device)
            icp.calibrate(calib_probs, y_calib)
            default_timing['ICP_Calibrate_Time'] = get_time(device) - t0

            # --- Predict Time ---
            t0 = get_time(device)
            prediction_regions = icp.predict(test_probs)
            default_timing['Predict_Time'] = get_time(device) - t0

            # --- Evaluate Time ---
            t0 = get_time(device)
            metrics = prediction_regions.evaluate(
                true_labelsets=y_test,
                significance_level=alphas,
                return_true_label_p_value=False,
                return_coverage=True,
                return_n_criterion=True,
                return_observed_fuzziness=False,
                return_observed_excess=False,
                return_s_criterion=False
            )
            default_timing['Evaluate_Time'] = get_time(device) - t0

            # --- Total time for default case ---
            default_timing['Case_Total_Time'] = (
                    default_timing['ICP_Init_Time'] +
                    default_timing['ICP_Calibrate_Time'] +
                    default_timing['Predict_Time'] +
                    default_timing['Evaluate_Time']
            )

            default_timing_records.append(default_timing)

            # Store coverage and size results for default case
            for a_idx, alpha in enumerate(alphas):
                coverage_results[device][case_key][iteration, a_idx] = metrics[alpha]['coverage']
                size_results[device][case_key][iteration, a_idx] = metrics[alpha]['n_criterion']

            del prediction_regions, metrics

            # =============================================================
            # PENALTY UPDATE CASES: Reuse calibrated ICP, only update weights
            # =============================================================
            for weight_name, (w_h, w_c) in penalty_weight_cases.items():
                case_key = f"{measure[:3].upper()} | {weight_name}"

                penalty_timing = {
                    'Iteration': iteration,
                    'Device': device,
                    'Measure': measure,
                    'Weight_Case': weight_name,
                    'W_H': w_h,
                    'W_C': w_c
                }

                # --- Penalty Update Time ---
                t0 = get_time(device)
                icp.weight_hamming = w_h
                icp.weight_cardinality = w_c

                # Force the engine to apply the new weights and re-sort the scores NOW!
                icp.calibrate()

                penalty_timing['Recalibration_Time'] = get_time(device) - t0

                # --- Predict Time ---
                t0 = get_time(device)
                prediction_regions = icp.predict(test_probs)
                penalty_timing['Predict_Time'] = get_time(device) - t0

                # --- Evaluate Time ---
                t0 = get_time(device)
                metrics = prediction_regions.evaluate(
                    true_labelsets=y_test,
                    significance_level=alphas,
                    return_true_label_p_value=False,
                    return_coverage=True,
                    return_n_criterion=True,
                    return_observed_fuzziness=False,
                    return_observed_excess=False,
                    return_s_criterion=False
                )
                penalty_timing['Evaluate_Time'] = get_time(device) - t0

                # --- Total time for penalty case ---
                penalty_timing['Case_Total_Time'] = (
                        penalty_timing['Recalibration_Time'] +
                        penalty_timing['Predict_Time'] +
                        penalty_timing['Evaluate_Time']
                )

                penalty_timing_records.append(penalty_timing)

                # Store coverage and size results
                for a_idx, alpha in enumerate(alphas):
                    coverage_results[device][case_key][iteration, a_idx] = metrics[alpha]['coverage']
                    size_results[device][case_key][iteration, a_idx] = metrics[alpha]['n_criterion']

                del prediction_regions, metrics

            # Cleanup ICP instance after all weight cases for this measure
            del icp
            cleanup_memory(device)

    # Aggressive memory cleanup per experiment
    del base_model, train_probs, calib_probs, test_probs
    del X_train, X_calib, X_test, y_train, y_calib, y_test
    cleanup_memory('cuda' if 'cuda' in devices else 'cpu')

# --- Process and Save DataFrames ---
print("\nProcessing results and saving DataFrames...")

# Create timing DataFrames
df_default = pd.DataFrame(default_timing_records)
df_penalty = pd.DataFrame(penalty_timing_records)

# Summary for default case (init, calibrate, predict, evaluate)
default_timing_cols = ['ICP_Init_Time', 'ICP_Calibrate_Time', 'Predict_Time', 'Evaluate_Time', 'Case_Total_Time']
df_default_summary = df_default.groupby(['Device', 'Measure'])[default_timing_cols].agg(['mean', 'std']).round(6)

print(f"\n--- Default Case (W_H=0, W_C=0) Timing Summary ---")
print(df_default_summary.to_string())

# Summary for penalty update cases
penalty_timing_cols = ['Recalibration_Time', 'Predict_Time', 'Evaluate_Time', 'Case_Total_Time']
df_penalty_summary = df_penalty.groupby(['Device', 'Measure', 'Weight_Case'])[penalty_timing_cols].agg(
    ['mean', 'std']).round(6)

print(f"\n--- Penalty Update Cases Timing Summary ---")
print(df_penalty_summary.to_string())

# Combined summary for comparison
print(f"\n--- Combined Timing Comparison ---")
df_default_avg = df_default.groupby(['Device', 'Measure'])[default_timing_cols].mean()
df_penalty_avg = df_penalty.groupby(['Device', 'Measure', 'Weight_Case'])[penalty_timing_cols].mean()
print("\nDefault Case (W_H=0, W_C=0):")
print(df_default_avg.to_string())
print("\nPenalty Update Cases:")
print(df_penalty_avg.to_string())

# --- 4. Coverage and Size Results ---
plot_device = 'cuda' if 'cuda' in devices else 'cpu'

df_coverage = pd.DataFrame(index=alphas)
df_sizes = pd.DataFrame(index=alphas)

for case_key in all_cases:
    df_coverage[case_key] = coverage_results[plot_device][case_key].mean(axis=0)
    df_sizes[case_key] = size_results[plot_device][case_key].mean(axis=0)

df_coverage.index.name = 'Alpha'
df_sizes.index.name = 'Alpha'

# --- 5. Save All Results ---
print("\nSaving all results to CSV files...")

# Raw timing data (for flexible re-analysis)
df_default.to_csv(f"{out_dir}/raw_timing_default_{dataset}.csv", index=False)
df_penalty.to_csv(f"{out_dir}/raw_timing_penalty_{dataset}.csv", index=False)

# Timing summaries
df_default_summary.to_csv(f"{out_dir}/timing_default_case_{dataset}.csv")
df_penalty_summary.to_csv(f"{out_dir}/timing_penalty_cases_{dataset}.csv")

# Coverage and size results
df_coverage.to_csv(f"{out_dir}/empirical_validity_{dataset}.csv")
df_sizes.to_csv(f"{out_dir}/prediction_sizes_{dataset}.csv")


total_end_time = time.perf_counter()
print(f"\n{'='*60}")
print(f"All experiments finished successfully!")
print(f"Total time: {total_end_time - total_start_time:.2f} seconds")
print(f"Results saved to: ./{out_dir}/")
print(f"{'='*60}")
print("\nSaved files:")
print(f"  - raw_timing_default_{dataset}.csv")
print(f"  - raw_timing_penalty_{dataset}.csv")
print(f"  - timing_default_case_{dataset}.csv")
print(f"  - timing_penalty_cases_{dataset}.csv")
print(f"  - empirical_validity_{dataset}.csv")
print(f"  - prediction_sizes_{dataset}.csv")
print(f"  - experiment_metadata.json")
# print(f"\nRun 'python plot_results.py' to generate plots.")


output_data_dir = os.path.join(out_dir, 'output_data')
if not os.path.exists(output_data_dir):
    os.makedirs(output_data_dir)


print('\nGenerating tables...')
# ==============================================================
#     Tex Table Prediction Region Percentages
# ===============================================================
df_sizes_restricted = df_sizes.loc[[0.01, 0.05, 0.1, 0.2]]
df_sizes_restricted['Min'] = df_sizes_restricted.min(axis=1)
df_sizes_restricted['Max'] = df_sizes_restricted.max(axis=1)
df_sizes_restricted = df_sizes_restricted[['Min', 'Max']]

df_sizes_restricted['Min_Pct'] = (((2 ** classes - df_sizes_restricted['Min']) / 2 ** classes) * 100)
df_sizes_restricted['Max_Pct'] = (((2 ** classes - df_sizes_restricted['Max']) / 2 ** classes) * 100)
df_sizes_restricted.drop(columns=['Min', 'Max'], inplace=True)
df_sizes_restricted.to_latex(os.path.join(output_data_dir, 'predidiction_sizes_percentages.tex'),
                             index=True)

print('\nTex Table Prediction Region Percentages finished')

# ===============================================================================
#  Tex Table Penalty Timing per Device and Weight Configuration
# ================================================================================
df_penalty_paper = df_penalty.copy()

df_penalty_paper = (
    df_penalty_paper
    .groupby(['Device', 'Measure', 'Weight_Case', 'W_H', 'W_C'])[
        ['Recalibration_Time', 'Predict_Time', 'Evaluate_Time', 'Case_Total_Time']
    ]
    .mean()
    .round(3)
    .reset_index()
)

df_penalty_paper.to_latex(
    os.path.join(output_data_dir, 'penalty_avg_timing.tex'),
    index=False,
    float_format='%.3f'
)

print('\nTex Table Penalty Timing per Device and Weight Configuration finished')

# ===============================================================================
#  Tex Table Default Timing per Device
# ================================================================================
df_default.drop(inplace=True, columns=['Iteration', 'Measure', 'Weight_Case', 'W_H', 'W_C'])
df_default_paper = df_default.groupby('Device')[
    ['ICP_Init_Time', 'ICP_Calibrate_Time', 'Predict_Time', 'Evaluate_Time', 'Case_Total_Time']].mean().round(
    3).reset_index()
df_default_paper.to_latex(os.path.join(output_data_dir, 'default_avg_timing_per_device.tex'),
                          index=False,
                          float_format='%.3f')

print('\nTex Table Default Timing per Device finished')

# --- Plotting Configuration ---
num_weight_cases = len(all_weight_cases)
mah_colors = plt.cm.viridis(
    np.linspace(0.15, 0.95, num_weight_cases)
)

norm_colors = plt.cm.plasma(
    np.linspace(0.15, 0.95, num_weight_cases)
)

#
#
# colors_mah = ['orange', 'teal', 'crimson', 'gold']
# colors_norm = ['gray', 'blue', 'green', 'purple']
# markers = ['o', 's', '^', 'd']

print("\nGenerating plots...")

# =============================================================================
# Plot 1: Prediction Region Sizes
# =============================================================================
# Figure size
plt.figure(figsize=(7, 5.5))

for case_key in all_cases:
    measure_type, weight_type = case_key.split(" | ")
    line_style = '-' if measure_type == 'MAH' else '--'
    colors = mah_colors if measure_type == 'MAH' else norm_colors
    color_idx = list(all_weight_cases.keys()).index(weight_type)

    # Linewidth and markersize
    marker = 'o' if measure_type == 'MAH' else 's'

    plt.plot(
        alphas,
        df_sizes[case_key],
        marker=marker,
        markevery=10,
        markersize=5,
        linewidth=2.5,
        linestyle=line_style,
        color=colors[color_idx],
        label=case_key,
        alpha=0.85
    )

# Font sizes
plt.xlabel('Significance Level ', fontsize=16)
plt.ylabel('Average Prediction Region Size (N-Criterion)', fontsize=16)
plt.title(f'{dataset.capitalize()} Dataset', fontsize=18)

# Axis tick numbers
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.xlim([0.0, 0.2])
plt.grid(True, linestyle=':', alpha=0.7)

# Legend
plt.legend(loc='upper right', fontsize=7, ncol=2, framealpha=0.9)

plt.tight_layout()
plt.savefig(f"{output_data_dir}/plot_prediction_sizes_{dataset}_paper.png", dpi=300)
plt.close()

print("  - Plot 1: Prediction Region Sizes finished")

# =============================================================================
# Plot 2: Empirical Validity
# =============================================================================
# Figure size (ideal for 0-to-1 calibration curves)
plt.figure(figsize=(7, 7))

for case_key in all_cases:
    measure_type, weight_type = case_key.split(" | ")
    line_style = '-' if measure_type == 'MAH' else '--'
    colors = mah_colors if measure_type == 'MAH' else norm_colors
    color_idx = list(all_weight_cases.keys()).index(weight_type)

    # Linewidth and markersize
    marker = 'o' if measure_type == 'MAH' else 's'

    plt.plot(
        alphas,
        df_coverage[case_key],
        marker=marker,
        markevery=10,
        markersize=5,
        linewidth=1.8,
        linestyle=line_style,
        color=colors[color_idx],
        label=case_key,
        alpha=0.85
    )

# Calibration line
plt.plot([0, 1], [1, 0], linestyle=':', color='red', linewidth=3, label='Perfect Calibration')

# Font size
plt.xlabel('Significance Level', fontsize=16)
plt.ylabel('Empirical Validity (Coverage)', fontsize=16)
plt.title(f'{dataset.capitalize()} Dataset', fontsize=18)

# Axis tick numbers
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.grid(True, linestyle=':', alpha=0.7)

# Legend
plt.legend(loc='upper right', fontsize=8, ncol=2, framealpha=0.9)

plt.tight_layout()
plt.savefig(f"{output_data_dir}/plot_empirical_validity_{dataset}.png", dpi=300)
plt.close()

print("  - Plot 2: Empirical Validity finished")


from IPython.display import Image, display

display(
    Image(
        filename=f"{output_data_dir}/plot_prediction_sizes_{dataset}_paper.png",
        width=700
    )
)

display(
    Image(
        filename=f"{output_data_dir}/plot_empirical_validity_{dataset}.png",
        width=700
    )
)


from IPython.display import Markdown, display

for filename in [
    "predidiction_sizes_percentages.tex",
    "penalty_avg_timing.tex",
    "default_avg_timing_per_device.tex",
]:
    with open(os.path.join(output_data_dir, filename), "r", encoding="utf-8") as f:
        tex_content = f.read()

    display(Markdown(f"## {filename}\n```latex\n{tex_content}\n```"))
# Out:
# Downloading X_yeast.csv...
# Downloading y_yeast.csv...
# Loading yeast dataset...
# X shape: (2417, 103), y shape: (2417, 14)
# CUDA detected! Will run a fair CPU vs GPU benchmark.
#
# Warming up CUDA context to prevent Fold 1 timing penalties...
# Total number of weight-case combinations: 8
# Cases: ['MAH | W_H=0, W_C=0', 'MAH | W_H=0.5, W_C=0.5', 'MAH | W_H=0.25, W_C=0.75', 'MAH | W_H=2.0, W_C=1.0', 'NOR | W_H=0, W_C=0', 'NOR | W_H=0.5, W_C=0.5', 'NOR | W_H=0.25, W_C=0.75', 'NOR | W_H=2.0, W_C=1.0']
#
# Starting 1 experiment(s)...
# Experiments:   0%|          | 0/1 [00:00<?, ?it/s]
# Predicting:   0%|          | 0/2 [00:00<?, ?it/s]
# Predicting:  50%|█████     | 1/2 [00:00<00:00,  2.62it/s]
# Predicting: 100%|██████████| 2/2 [00:00<00:00,  2.59it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:   9%|▉         | 9/99 [00:00<00:01, 82.03it/s]
# Evaluating Metrics:  19%|█▉        | 19/99 [00:00<00:00, 89.81it/s]
# Evaluating Metrics:  29%|██▉       | 29/99 [00:00<00:00, 92.32it/s]
# Evaluating Metrics:  39%|███▉      | 39/99 [00:00<00:00, 92.93it/s]
# Evaluating Metrics:  49%|████▉     | 49/99 [00:00<00:00, 92.76it/s]
# Evaluating Metrics:  60%|█████▉    | 59/99 [00:00<00:00, 74.76it/s]
# Evaluating Metrics:  68%|██████▊   | 67/99 [00:00<00:00, 66.47it/s]
# Evaluating Metrics:  76%|███████▌  | 75/99 [00:01<00:00, 59.96it/s]
# Evaluating Metrics:  83%|████████▎ | 82/99 [00:01<00:00, 57.37it/s]
# Evaluating Metrics:  89%|████████▉ | 88/99 [00:01<00:00, 56.08it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 65.96it/s]
#
# Calculating Hamming Penalties:   0%|          | 0/12 [00:00<?, ?it/s]
# Calculating Hamming Penalties: 100%|██████████| 12/12 [00:00<00:00, 105.32it/s]
#
# Predicting:   0%|          | 0/2 [00:00<?, ?it/s]
# Predicting:  50%|█████     | 1/2 [00:00<00:00,  2.48it/s]
# Predicting: 100%|██████████| 2/2 [00:00<00:00,  2.54it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:  11%|█         | 11/99 [00:00<00:00, 100.69it/s]
# Evaluating Metrics:  22%|██▏       | 22/99 [00:00<00:00, 98.53it/s]
# Evaluating Metrics:  32%|███▏      | 32/99 [00:00<00:00, 98.18it/s]
# Evaluating Metrics:  42%|████▏     | 42/99 [00:00<00:00, 96.86it/s]
# Evaluating Metrics:  53%|█████▎    | 52/99 [00:00<00:00, 95.34it/s]
# Evaluating Metrics:  63%|██████▎   | 62/99 [00:00<00:00, 93.11it/s]
# Evaluating Metrics:  73%|███████▎  | 72/99 [00:00<00:00, 78.43it/s]
# Evaluating Metrics:  82%|████████▏ | 81/99 [00:00<00:00, 68.80it/s]
# Evaluating Metrics:  90%|████████▉ | 89/99 [00:01<00:00, 62.97it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 73.60it/s]
#
# Predicting:   0%|          | 0/2 [00:00<?, ?it/s]
# Predicting:  50%|█████     | 1/2 [00:00<00:00,  2.51it/s]
# Predicting: 100%|██████████| 2/2 [00:00<00:00,  2.56it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:  10%|█         | 10/99 [00:00<00:00, 95.42it/s]
# Evaluating Metrics:  20%|██        | 20/99 [00:00<00:00, 93.29it/s]
# Evaluating Metrics:  30%|███       | 30/99 [00:00<00:00, 94.78it/s]
# Evaluating Metrics:  40%|████      | 40/99 [00:00<00:00, 93.87it/s]
# Evaluating Metrics:  51%|█████     | 50/99 [00:00<00:00, 91.67it/s]
# Evaluating Metrics:  61%|██████    | 60/99 [00:00<00:00, 92.86it/s]
# Evaluating Metrics:  71%|███████   | 70/99 [00:00<00:00, 82.31it/s]
# Evaluating Metrics:  80%|███████▉  | 79/99 [00:00<00:00, 70.21it/s]
# Evaluating Metrics:  88%|████████▊ | 87/99 [00:01<00:00, 64.23it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 68.80it/s]
#
# Predicting:   0%|          | 0/2 [00:00<?, ?it/s]
# Predicting:  50%|█████     | 1/2 [00:00<00:00,  1.91it/s]
# Predicting: 100%|██████████| 2/2 [00:01<00:00,  1.94it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:   8%|▊         | 8/99 [00:00<00:01, 77.93it/s]
# Evaluating Metrics:  16%|█▌        | 16/99 [00:00<00:01, 73.71it/s]
# Evaluating Metrics:  24%|██▍       | 24/99 [00:00<00:01, 72.00it/s]
# Evaluating Metrics:  32%|███▏      | 32/99 [00:00<00:00, 71.82it/s]
# Evaluating Metrics:  40%|████      | 40/99 [00:00<00:00, 70.44it/s]
# Evaluating Metrics:  48%|████▊     | 48/99 [00:00<00:00, 70.34it/s]
# Evaluating Metrics:  57%|█████▋    | 56/99 [00:00<00:00, 71.19it/s]
# Evaluating Metrics:  65%|██████▍   | 64/99 [00:00<00:00, 63.63it/s]
# Evaluating Metrics:  72%|███████▏  | 71/99 [00:01<00:00, 54.59it/s]
# Evaluating Metrics:  78%|███████▊  | 77/99 [00:01<00:00, 48.58it/s]
# Evaluating Metrics:  84%|████████▍ | 83/99 [00:01<00:00, 45.55it/s]
# Evaluating Metrics:  89%|████████▉ | 88/99 [00:01<00:00, 43.90it/s]
# Evaluating Metrics:  94%|█████████▍| 93/99 [00:01<00:00, 42.63it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 53.82it/s]
#
# Predicting:   0%|          | 0/2 [00:00<?, ?it/s]
# Predicting:  50%|█████     | 1/2 [00:00<00:00,  1.83it/s]
# Predicting: 100%|██████████| 2/2 [00:01<00:00,  1.97it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:  11%|█         | 11/99 [00:00<00:00, 100.67it/s]
# Evaluating Metrics:  22%|██▏       | 22/99 [00:00<00:00, 94.61it/s]
# Evaluating Metrics:  32%|███▏      | 32/99 [00:00<00:00, 95.77it/s]
# Evaluating Metrics:  42%|████▏     | 42/99 [00:00<00:00, 97.15it/s]
# Evaluating Metrics:  53%|█████▎    | 52/99 [00:00<00:00, 97.19it/s]
# Evaluating Metrics:  63%|██████▎   | 62/99 [00:00<00:00, 97.05it/s]
# Evaluating Metrics:  73%|███████▎  | 72/99 [00:00<00:00, 89.48it/s]
# Evaluating Metrics:  83%|████████▎ | 82/99 [00:00<00:00, 74.41it/s]
# Evaluating Metrics:  91%|█████████ | 90/99 [00:01<00:00, 67.41it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 76.81it/s]
#
# Calculating Hamming Penalties: 100%|██████████| 12/12 [00:00<00:00, 130.39it/s]
#
# Predicting:   0%|          | 0/2 [00:00<?, ?it/s]
# Predicting:  50%|█████     | 1/2 [00:00<00:00,  2.61it/s]
# Predicting: 100%|██████████| 2/2 [00:00<00:00,  2.63it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:   9%|▉         | 9/99 [00:00<00:01, 89.10it/s]
# Evaluating Metrics:  19%|█▉        | 19/99 [00:00<00:00, 93.07it/s]
# Evaluating Metrics:  29%|██▉       | 29/99 [00:00<00:00, 95.63it/s]
# Evaluating Metrics:  39%|███▉      | 39/99 [00:00<00:00, 95.40it/s]
# Evaluating Metrics:  49%|████▉     | 49/99 [00:00<00:00, 95.00it/s]
# Evaluating Metrics:  60%|█████▉    | 59/99 [00:00<00:00, 94.38it/s]
# Evaluating Metrics:  70%|██████▉   | 69/99 [00:00<00:00, 79.16it/s]
# Evaluating Metrics:  79%|███████▉  | 78/99 [00:00<00:00, 69.33it/s]
# Evaluating Metrics:  87%|████████▋ | 86/99 [00:01<00:00, 62.97it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 72.22it/s]
#
# Predicting:   0%|          | 0/2 [00:00<?, ?it/s]
# Predicting:  50%|█████     | 1/2 [00:00<00:00,  2.59it/s]
# Predicting: 100%|██████████| 2/2 [00:00<00:00,  2.58it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:  10%|█         | 10/99 [00:00<00:00, 97.85it/s]
# Evaluating Metrics:  20%|██        | 20/99 [00:00<00:00, 97.49it/s]
# Evaluating Metrics:  31%|███▏      | 31/99 [00:00<00:00, 98.82it/s]
# Evaluating Metrics:  41%|████▏     | 41/99 [00:00<00:00, 95.20it/s]
# Evaluating Metrics:  52%|█████▏    | 51/99 [00:00<00:00, 94.61it/s]
# Evaluating Metrics:  62%|██████▏   | 61/99 [00:00<00:00, 95.64it/s]
# Evaluating Metrics:  72%|███████▏  | 71/99 [00:00<00:00, 78.66it/s]
# Evaluating Metrics:  81%|████████  | 80/99 [00:00<00:00, 68.08it/s]
# Evaluating Metrics:  89%|████████▉ | 88/99 [00:01<00:00, 61.66it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 72.77it/s]
#
# Predicting:   0%|          | 0/2 [00:00<?, ?it/s]
# Predicting:  50%|█████     | 1/2 [00:00<00:00,  2.63it/s]
# Predicting: 100%|██████████| 2/2 [00:00<00:00,  2.61it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:  10%|█         | 10/99 [00:00<00:00, 94.79it/s]
# Evaluating Metrics:  20%|██        | 20/99 [00:00<00:00, 94.40it/s]
# Evaluating Metrics:  30%|███       | 30/99 [00:00<00:00, 96.72it/s]
# Evaluating Metrics:  41%|████▏     | 41/99 [00:00<00:00, 98.51it/s]
# Evaluating Metrics:  52%|█████▏    | 51/99 [00:00<00:00, 98.71it/s]
# Evaluating Metrics:  63%|██████▎   | 62/99 [00:00<00:00, 99.56it/s]
# Evaluating Metrics:  73%|███████▎  | 72/99 [00:00<00:00, 82.89it/s]
# Evaluating Metrics:  82%|████████▏ | 81/99 [00:00<00:00, 69.05it/s]
# Evaluating Metrics:  90%|████████▉ | 89/99 [00:01<00:00, 62.71it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 74.05it/s]
#
# Predicting: 100%|██████████| 1/1 [00:00<00:00, 16.65it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:  10%|█         | 10/99 [00:00<00:01, 83.60it/s]
# Evaluating Metrics:  19%|█▉        | 19/99 [00:00<00:01, 76.89it/s]
# Evaluating Metrics:  27%|██▋       | 27/99 [00:00<00:00, 77.61it/s]
# Evaluating Metrics:  37%|███▋      | 37/99 [00:00<00:00, 85.18it/s]
# Evaluating Metrics:  46%|████▋     | 46/99 [00:00<00:00, 85.24it/s]
# Evaluating Metrics:  56%|█████▌    | 55/99 [00:00<00:00, 77.31it/s]
# Evaluating Metrics:  64%|██████▎   | 63/99 [00:00<00:00, 62.71it/s]
# Evaluating Metrics:  71%|███████   | 70/99 [00:01<00:00, 54.02it/s]
# Evaluating Metrics:  77%|███████▋  | 76/99 [00:01<00:00, 47.60it/s]
# Evaluating Metrics:  83%|████████▎ | 82/99 [00:01<00:00, 42.50it/s]
# Evaluating Metrics:  88%|████████▊ | 87/99 [00:01<00:00, 39.15it/s]
# Evaluating Metrics:  93%|█████████▎| 92/99 [00:01<00:00, 38.48it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 52.73it/s]
#
# Calculating Hamming Penalties: 100%|██████████| 5/5 [00:00<00:00, 192.27it/s]
#
# Predicting: 100%|██████████| 1/1 [00:00<00:00, 26.02it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:   6%|▌         | 6/99 [00:00<00:01, 53.23it/s]
# Evaluating Metrics:  13%|█▎        | 13/99 [00:00<00:01, 60.44it/s]
# Evaluating Metrics:  20%|██        | 20/99 [00:00<00:01, 63.42it/s]
# Evaluating Metrics:  27%|██▋       | 27/99 [00:00<00:01, 64.98it/s]
# Evaluating Metrics:  34%|███▍      | 34/99 [00:00<00:01, 64.55it/s]
# Evaluating Metrics:  41%|████▏     | 41/99 [00:00<00:00, 63.72it/s]
# Evaluating Metrics:  48%|████▊     | 48/99 [00:00<00:00, 63.05it/s]
# Evaluating Metrics:  56%|█████▌    | 55/99 [00:00<00:00, 64.46it/s]
# Evaluating Metrics:  63%|██████▎   | 62/99 [00:00<00:00, 65.43it/s]
# Evaluating Metrics:  70%|██████▉   | 69/99 [00:01<00:00, 57.63it/s]
# Evaluating Metrics:  76%|███████▌  | 75/99 [00:01<00:00, 50.85it/s]
# Evaluating Metrics:  82%|████████▏ | 81/99 [00:01<00:00, 46.57it/s]
# Evaluating Metrics:  87%|████████▋ | 86/99 [00:01<00:00, 44.28it/s]
# Evaluating Metrics:  92%|█████████▏| 91/99 [00:01<00:00, 42.26it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 51.76it/s]
#
# Predicting: 100%|██████████| 1/1 [00:00<00:00, 44.76it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:   6%|▌         | 6/99 [00:00<00:01, 58.04it/s]
# Evaluating Metrics:  14%|█▍        | 14/99 [00:00<00:01, 66.37it/s]
# Evaluating Metrics:  22%|██▏       | 22/99 [00:00<00:01, 68.98it/s]
# Evaluating Metrics:  29%|██▉       | 29/99 [00:00<00:01, 66.90it/s]
# Evaluating Metrics:  36%|███▋      | 36/99 [00:00<00:00, 67.75it/s]
# Evaluating Metrics:  43%|████▎     | 43/99 [00:00<00:00, 68.28it/s]
# Evaluating Metrics:  51%|█████     | 50/99 [00:00<00:00, 64.96it/s]
# Evaluating Metrics:  58%|█████▊    | 57/99 [00:00<00:00, 61.28it/s]
# Evaluating Metrics:  65%|██████▍   | 64/99 [00:00<00:00, 62.69it/s]
# Evaluating Metrics:  72%|███████▏  | 71/99 [00:01<00:00, 54.88it/s]
# Evaluating Metrics:  78%|███████▊  | 77/99 [00:01<00:00, 48.60it/s]
# Evaluating Metrics:  84%|████████▍ | 83/99 [00:01<00:00, 47.87it/s]
# Evaluating Metrics:  89%|████████▉ | 88/99 [00:01<00:00, 47.25it/s]
# Evaluating Metrics:  94%|█████████▍| 93/99 [00:01<00:00, 46.67it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 54.96it/s]
#
# Predicting: 100%|██████████| 1/1 [00:00<00:00, 45.91it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:   7%|▋         | 7/99 [00:00<00:01, 64.19it/s]
# Evaluating Metrics:  17%|█▋        | 17/99 [00:00<00:01, 80.66it/s]
# Evaluating Metrics:  27%|██▋       | 27/99 [00:00<00:00, 86.94it/s]
# Evaluating Metrics:  37%|███▋      | 37/99 [00:00<00:00, 88.97it/s]
# Evaluating Metrics:  47%|████▋     | 47/99 [00:00<00:00, 90.32it/s]
# Evaluating Metrics:  58%|█████▊    | 57/99 [00:00<00:00, 91.08it/s]
# Evaluating Metrics:  68%|██████▊   | 67/99 [00:00<00:00, 78.51it/s]
# Evaluating Metrics:  77%|███████▋  | 76/99 [00:00<00:00, 68.15it/s]
# Evaluating Metrics:  85%|████████▍ | 84/99 [00:01<00:00, 61.77it/s]
# Evaluating Metrics:  92%|█████████▏| 91/99 [00:01<00:00, 55.61it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 67.48it/s]
#
# Predicting: 100%|██████████| 1/1 [00:00<00:00, 43.33it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:  10%|█         | 10/99 [00:00<00:00, 93.41it/s]
# Evaluating Metrics:  20%|██        | 20/99 [00:00<00:00, 95.78it/s]
# Evaluating Metrics:  30%|███       | 30/99 [00:00<00:00, 97.21it/s]
# Evaluating Metrics:  40%|████      | 40/99 [00:00<00:00, 92.93it/s]
# Evaluating Metrics:  51%|█████     | 50/99 [00:00<00:00, 95.29it/s]
# Evaluating Metrics:  61%|██████    | 60/99 [00:00<00:00, 96.79it/s]
# Evaluating Metrics:  71%|███████   | 70/99 [00:00<00:00, 96.32it/s]
# Evaluating Metrics:  81%|████████  | 80/99 [00:00<00:00, 76.82it/s]
# Evaluating Metrics:  90%|████████▉ | 89/99 [00:01<00:00, 68.68it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 77.70it/s]
#
# Calculating Hamming Penalties: 100%|██████████| 5/5 [00:00<00:00, 1293.58it/s]
#
# Predicting: 100%|██████████| 1/1 [00:00<00:00, 45.95it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:   9%|▉         | 9/99 [00:00<00:01, 83.75it/s]
# Evaluating Metrics:  19%|█▉        | 19/99 [00:00<00:00, 92.55it/s]
# Evaluating Metrics:  29%|██▉       | 29/99 [00:00<00:00, 94.74it/s]
# Evaluating Metrics:  39%|███▉      | 39/99 [00:00<00:00, 96.61it/s]
# Evaluating Metrics:  49%|████▉     | 49/99 [00:00<00:00, 96.38it/s]
# Evaluating Metrics:  60%|█████▉    | 59/99 [00:00<00:00, 96.52it/s]
# Evaluating Metrics:  70%|██████▉   | 69/99 [00:00<00:00, 79.58it/s]
# Evaluating Metrics:  79%|███████▉  | 78/99 [00:00<00:00, 68.98it/s]
# Evaluating Metrics:  87%|████████▋ | 86/99 [00:01<00:00, 62.59it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 72.18it/s]
#
# Predicting: 100%|██████████| 1/1 [00:00<00:00, 45.18it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:   7%|▋         | 7/99 [00:00<00:01, 68.28it/s]
# Evaluating Metrics:  16%|█▌        | 16/99 [00:00<00:01, 80.47it/s]
# Evaluating Metrics:  25%|██▌       | 25/99 [00:00<00:00, 84.03it/s]
# Evaluating Metrics:  35%|███▌      | 35/99 [00:00<00:00, 86.98it/s]
# Evaluating Metrics:  45%|████▌     | 45/99 [00:00<00:00, 89.55it/s]
# Evaluating Metrics:  56%|█████▌    | 55/99 [00:00<00:00, 90.78it/s]
# Evaluating Metrics:  66%|██████▌   | 65/99 [00:00<00:00, 84.55it/s]
# Evaluating Metrics:  75%|███████▍  | 74/99 [00:00<00:00, 69.88it/s]
# Evaluating Metrics:  83%|████████▎ | 82/99 [00:01<00:00, 61.87it/s]
# Evaluating Metrics:  90%|████████▉ | 89/99 [00:01<00:00, 56.80it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 66.71it/s]
#
# Predicting: 100%|██████████| 1/1 [00:00<00:00, 35.90it/s]
#
# Evaluating Metrics:   0%|          | 0/99 [00:00<?, ?it/s]
# Evaluating Metrics:   7%|▋         | 7/99 [00:00<00:01, 69.75it/s]
# Evaluating Metrics:  17%|█▋        | 17/99 [00:00<00:01, 81.95it/s]
# Evaluating Metrics:  26%|██▋       | 26/99 [00:00<00:00, 83.62it/s]
# Evaluating Metrics:  36%|███▋      | 36/99 [00:00<00:00, 88.09it/s]
# Evaluating Metrics:  46%|████▋     | 46/99 [00:00<00:00, 90.17it/s]
# Evaluating Metrics:  57%|█████▋    | 56/99 [00:00<00:00, 91.70it/s]
# Evaluating Metrics:  67%|██████▋   | 66/99 [00:00<00:00, 89.26it/s]
# Evaluating Metrics:  76%|███████▌  | 75/99 [00:00<00:00, 70.90it/s]
# Evaluating Metrics:  84%|████████▍ | 83/99 [00:01<00:00, 65.13it/s]
# Evaluating Metrics:  91%|█████████ | 90/99 [00:01<00:00, 60.15it/s]
# Evaluating Metrics: 100%|██████████| 99/99 [00:01<00:00, 68.74it/s]
# Experiments: 100%|██████████| 1/1 [00:57<00:00, 57.80s/it]
# Processing results and saving DataFrames...
#
# --- Default Case (W_H=0, W_C=0) Timing Summary ---
#                    ICP_Init_Time     ICP_Calibrate_Time     Predict_Time     Evaluate_Time     Case_Total_Time
#                             mean std               mean std         mean std          mean std            mean std
# Device Measure
# cpu    mahalanobis      0.197804 NaN           0.022230 NaN     0.781433 NaN      1.519724 NaN        2.521191 NaN
#        norm             0.004794 NaN           0.000860 NaN     1.026958 NaN      1.296085 NaN        2.328697 NaN
# cuda   mahalanobis      0.603566 NaN           0.227322 NaN     0.075195 NaN      1.890071 NaN        2.796155 NaN
#        norm             0.009367 NaN           0.000955 NaN     0.041148 NaN      1.283740 NaN        1.335209 NaN
#
# --- Penalty Update Cases Timing Summary ---
#                                       Recalibration_Time     Predict_Time     Evaluate_Time     Case_Total_Time
#                                                     mean std         mean std          mean std            mean std
# Device Measure     Weight_Case
# cpu    mahalanobis W_H=0.25, W_C=0.75           0.001167 NaN     0.791701 NaN      1.447711 NaN        2.240580 NaN
#                    W_H=0.5, W_C=0.5             0.123361 NaN     0.795572 NaN      1.355568 NaN        2.274502 NaN
#                    W_H=2.0, W_C=1.0             0.000364 NaN     1.046932 NaN      1.846378 NaN        2.893675 NaN
#        norm        W_H=0.25, W_C=0.75           0.002192 NaN     0.788293 NaN      1.371143 NaN        2.161628 NaN
#                    W_H=0.5, W_C=0.5             0.099611 NaN     0.771960 NaN      1.381264 NaN        2.252835 NaN
#                    W_H=2.0, W_C=1.0             0.000772 NaN     0.773863 NaN      1.346450 NaN        2.121085 NaN
# cuda   mahalanobis W_H=0.25, W_C=0.75           0.000478 NaN     0.029575 NaN      1.808599 NaN        1.838652 NaN
#                    W_H=0.5, W_C=0.5             0.094424 NaN     0.051112 NaN      1.922658 NaN        2.068194 NaN
#                    W_H=2.0, W_C=1.0             0.001270 NaN     0.031048 NaN      1.475721 NaN        1.508040 NaN
#        norm        W_H=0.25, W_C=0.75           0.001412 NaN     0.033248 NaN      1.491901 NaN        1.526560 NaN
#                    W_H=0.5, W_C=0.5             0.010236 NaN     0.028800 NaN      1.378999 NaN        1.418034 NaN
#                    W_H=2.0, W_C=1.0             0.000577 NaN     0.047721 NaN      1.449874 NaN        1.498172 NaN
#
# --- Combined Timing Comparison ---
#
# Default Case (W_H=0, W_C=0):
#                     ICP_Init_Time  ICP_Calibrate_Time  Predict_Time  Evaluate_Time  Case_Total_Time
# Device Measure
# cpu    mahalanobis       0.197804            0.022230      0.781433       1.519724         2.521191
#        norm              0.004794            0.000860      1.026958       1.296085         2.328697
# cuda   mahalanobis       0.603566            0.227322      0.075195       1.890071         2.796155
#        norm              0.009367            0.000955      0.041148       1.283740         1.335209
#
# Penalty Update Cases:
#                                        Recalibration_Time  Predict_Time  Evaluate_Time  Case_Total_Time
# Device Measure     Weight_Case
# cpu    mahalanobis W_H=0.25, W_C=0.75            0.001167      0.791701       1.447711         2.240580
#                    W_H=0.5, W_C=0.5              0.123361      0.795572       1.355568         2.274502
#                    W_H=2.0, W_C=1.0              0.000364      1.046932       1.846378         2.893675
#        norm        W_H=0.25, W_C=0.75            0.002192      0.788293       1.371143         2.161628
#                    W_H=0.5, W_C=0.5              0.099611      0.771960       1.381264         2.252835
#                    W_H=2.0, W_C=1.0              0.000772      0.773863       1.346450         2.121085
# cuda   mahalanobis W_H=0.25, W_C=0.75            0.000478      0.029575       1.808599         1.838652
#                    W_H=0.5, W_C=0.5              0.094424      0.051112       1.922658         2.068194
#                    W_H=2.0, W_C=1.0              0.001270      0.031048       1.475721         1.508040
#        norm        W_H=0.25, W_C=0.75            0.001412      0.033248       1.491901         1.526560
#                    W_H=0.5, W_C=0.5              0.010236      0.028800       1.378999         1.418034
#                    W_H=2.0, W_C=1.0              0.000577      0.047721       1.449874         1.498172
#
# Saving all results to CSV files...
#
# ============================================================
# All experiments finished successfully!
# Total time: 57.89 seconds
# Results saved to: ./yeast_experiments/
# ============================================================
#
# Saved files:
#   - raw_timing_default_yeast.csv
#   - raw_timing_penalty_yeast.csv
#   - timing_default_case_yeast.csv
#   - timing_penalty_cases_yeast.csv
#   - empirical_validity_yeast.csv
#   - prediction_sizes_yeast.csv
#   - experiment_metadata.json
#
# Generating tables...
#
# Tex Table Prediction Region Percentages finished
#
# Tex Table Penalty Timing per Device and Weight Configuration finished
#
# Tex Table Default Timing per Device finished
#
# Generating plots...
#   - Plot 1: Prediction Region Sizes finished
#   - Plot 2: Empirical Validity finished
# ## predidiction_sizes_percentages.tex
# ```latex
# \begin{tabular}{lrr}
# \toprule
#  & Min_Pct & Max_Pct \\
# Alpha &  &  \\
# \midrule
# 0.010000 & 87.250286 & 50.259172 \\
# 0.050000 & 94.798392 & 74.306999 \\
# 0.100000 & 96.103460 & 84.422618 \\
# 0.200000 & 98.157243 & 92.895508 \\
# \bottomrule
# \end{tabular}
#
# ```
# ## penalty_avg_timing.tex
# ```latex
# \begin{tabular}{lllrrrrrr}
# \toprule
# Device & Measure & Weight_Case & W_H & W_C & Recalibration_Time & Predict_Time & Evaluate_Time & Case_Total_Time \\
# \midrule
# cpu & mahalanobis & W_H=0.25, W_C=0.75 & 0.250 & 0.750 & 0.001 & 0.792 & 1.448 & 2.241 \\
# cpu & mahalanobis & W_H=0.5, W_C=0.5 & 0.500 & 0.500 & 0.123 & 0.796 & 1.356 & 2.275 \\
# cpu & mahalanobis & W_H=2.0, W_C=1.0 & 2.000 & 1.000 & 0.000 & 1.047 & 1.846 & 2.894 \\
# cpu & norm & W_H=0.25, W_C=0.75 & 0.250 & 0.750 & 0.002 & 0.788 & 1.371 & 2.162 \\
# cpu & norm & W_H=0.5, W_C=0.5 & 0.500 & 0.500 & 0.100 & 0.772 & 1.381 & 2.253 \\
# cpu & norm & W_H=2.0, W_C=1.0 & 2.000 & 1.000 & 0.001 & 0.774 & 1.346 & 2.121 \\
# cuda & mahalanobis & W_H=0.25, W_C=0.75 & 0.250 & 0.750 & 0.000 & 0.030 & 1.809 & 1.839 \\
# cuda & mahalanobis & W_H=0.5, W_C=0.5 & 0.500 & 0.500 & 0.094 & 0.051 & 1.923 & 2.068 \\
# cuda & mahalanobis & W_H=2.0, W_C=1.0 & 2.000 & 1.000 & 0.001 & 0.031 & 1.476 & 1.508 \\
# cuda & norm & W_H=0.25, W_C=0.75 & 0.250 & 0.750 & 0.001 & 0.033 & 1.492 & 1.527 \\
# cuda & norm & W_H=0.5, W_C=0.5 & 0.500 & 0.500 & 0.010 & 0.029 & 1.379 & 1.418 \\
# cuda & norm & W_H=2.0, W_C=1.0 & 2.000 & 1.000 & 0.001 & 0.048 & 1.450 & 1.498 \\
# \bottomrule
# \end{tabular}
#
# ```
# ## default_avg_timing_per_device.tex
# ```latex
# \begin{tabular}{lrrrrr}
# \toprule
# Device & ICP_Init_Time & ICP_Calibrate_Time & Predict_Time & Evaluate_Time & Case_Total_Time \\
# \midrule
# cpu & 0.101 & 0.012 & 0.904 & 1.408 & 2.425 \\
# cuda & 0.306 & 0.114 & 0.058 & 1.587 & 2.066 \\
# \bottomrule
# \end{tabular}
#
# ```
